# %%
import csv

import os 


class matrimony:

    filename="data.csv"

    def Insertion(self):

        self.name=input("your name:") 

        self.phone_no=input("Your phone no:")

        self.gender=input("Gender: ") 

        self.dob=input("your Date of Birth")

        self.qualification=input("your qualification:") 

        self.hobby=input("Your Hobbies: ") 

        self.mother_tongue=input("Your mother Tongue:") 

        self.preferences=input("your preference about yor partner:")

        self.salary=input("your salary:") 

        self.country=input("country: ")

        with open (db.filename, 'a', newline='') as file:

            csvwriter = csv.writer(file)

            csvwriter.writerow([self.name, self.phone_no, self.gender, self.dob, self.qualification, self.hobby, self.mother_tongue, self.preferences, self.salary, self.country])

    def Retrival (self): 
                            
        print("*"*34)

        print("name:\t\t,phone_no:\t\t,gender:\t\t,dob:\t\t,qualification:\t\t,hobby:\t\t,mother_tongue:\t\t,preferences:\t\t,salary:\t\t,country:")
        
        with open(self.filename,'r') as file:

            print("*"*34)

        with open (db. filename, 'r') as file:
        
            data = csv.reader (file)

            for row in list(data): 
                print(row[0],"\t\t",row[1],"\t\t",row[2],"\t\t",row[3],"\t\t",row[4],"\t\t",row[5],"\t\t",row[6],"\t\t",row[7])

                print("-"*34)

        print("your data saved successfully")

    def Searching(self):

        search_elt=input("Enter the name to search:")

        print("name:\t\t,phone_no:\t\t,gender:\t\t,dob:\t\t,qualification:\t\t,hobby:\t\t,mother_tongue:\t\t,preferences:\t\t,salary:\t\t,country:")
        with open(self.filename, 'r') as file:
            data=csv.reader (file)

            namelist=list(data)
            s_result=[names for names in namelist if search_elt in names]

            if len(s_result)>0:

                for row in s_result:

                    print(row[0],"\t\t",row[1],"\t\t",row[2],"\t\t",row[3],"\t\t",row[4],"\t\t",row[5],"\t\t",row[6],"\t\t",row[7])

                else:

                    print("No Results Found")

    def Deletion(self):

        name_elt=input("Enter the persons name to delete:") 
                          
        with open(self.filename, 'r') as file:

            data=csv.reader (file)

            namelist=list(data)

            f_result = [names for names in namelist if name_elt !=names[0]]
                        
        with open(self.filename, 'w',newline="")as file:

            csvwriter = csv.writer(file)

            csvwriter.writerows (f_result) 
                  
            if(len(f_result) == len(namelist)):
            
                print("Nothing is available to delete")

            else:

                print("updated list")

        self. Retrival()

    def menu(self):

        print("0. Exit") 
                  
        print("1.Insertion")

        print("2.Modification")

        print("3.Retrival")

        print("4.Searching") 
                  
        print("5.Recommendation")

        print("6.Deletion") 
                  
        mychoice=None

        try:

            mychoice=int(input("Enter the Choice:"))

        except:

            logging.error("Enter the Choice")
                  
        return mychoice

        print("Welcome to matrimony Application in Choose your peter Happily!!!!")

db= matrimony()

c = db.menu()

while True:

    if c==0:
        break
    elif c==1:
        db.Insertion()
        break
    elif c==2:
        db.Retrival()
        break
    elif c==3:
        db. Searching()
        break
    elif c==4:
        db.Deletion()
        break
    else:
        pass
# Out:
# 0. Exit
# 1.Insertion
# 2.Modification
# 3.Retrival
# 4.Searching
# 5.Recommendation
# 6.Deletion
# Enter the Choice:1
# your name:soundharya
# Your phone no:36748
# Gender: f
# your Date of Birth3673
# your qualification:b.e
# Your Hobbies: it
# Your mother Tongue:ta
# your preference about yor partner:ajs
# your salary:378483
# country: india
